# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import matplotlib as mpl
import dartwork_mpl as dmpl
# Out:
# Load colors...
# Load colormaps...

# %%
fig, axs = dmpl.util.plot_colormaps(['dm.Tempo_r', 'dm.Tempo'])

# %%
dmpl.save_formats(fig, 'colormaps', ['png'])
